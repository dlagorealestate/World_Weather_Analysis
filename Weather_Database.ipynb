# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

# Identify nearest city 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 619

# %%
# Import the request library.
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=97eaf8e7f85553428d213a85184fc41b

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | san ignacio
# Processing Record 2 of Set 1 | marienburg
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | deputatskiy
# Processing Record 6 of Set 1 | haines junction
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | mayumba
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | bubaque
# Processing Record 18 of Set 1 | san marcos
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | severnoye
# Processing Record 21 of Set 1 | bambous virieux
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | benjamin constant
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | saint-pierre
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | rockport
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | vanimo
# Processing Record 33 of Set 1 | umm lajj
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | flinders
# Processing Record 37 of Set 1 | yar-sale
# Processing Record 38 of Set 1 | port macquarie
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | aykhal
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | ixtapa
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | nemuro
# Processing Record 46 of Set 1 | isangel
# Processing Record 47 of Set 1 | ewa beach
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | geraldton
# Processing Record 1 of Set 2 | saint-paul
# Processing Record 2 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 2 | pisco
# Processing Record 4 of Set 2 | okahandja
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | show low
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | husavik
# Processing Record 12 of Set 2 | bacolod
# Processing Record 13 of Set 2 | ovruch
# Processing Record 14 of Set 2 | ivanteyevka
# Processing Record 15 of Set 2 | primorsk
# Processing Record 16 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | kuva
# City not found. Skipping...
# Processing Record 19 of Set 2 | axim
# Processing Record 20 of Set 2 | nouadhibou
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | spirit river
# Processing Record 24 of Set 2 | cosambesti
# Processing Record 25 of Set 2 | smithers
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | lasa
# Processing Record 28 of Set 2 | beloha
# Processing Record 29 of Set 2 | marsh harbour
# Processing Record 30 of Set 2 | tianpeng
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | salinopolis
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | tuatapere
# Processing Record 35 of Set 2 | algiers
# Processing Record 36 of Set 2 | tres arroyos
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | alofi
# Processing Record 39 of Set 2 | kushima
# Processing Record 40 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 2 | laurel
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | patea
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | saldanha
# Processing Record 49 of Set 2 | beberibe
# Processing Record 50 of Set 2 | zlobin
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | pierre
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | jhikargachha
# City not found. Skipping...
# Processing Record 5 of Set 3 | windhoek
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | williams lake
# Processing Record 8 of Set 3 | maine-soroa
# Processing Record 9 of Set 3 | dongsheng
# Processing Record 10 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 3 | katsuura
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | comodoro rivadavia
# Processing Record 15 of Set 3 | placido de castro
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | anadyr
# Processing Record 20 of Set 3 | elverum
# Processing Record 21 of Set 3 | luganville
# Processing Record 22 of Set 3 | pevek
# Processing Record 23 of Set 3 | dalby
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | ahipara
# Processing Record 26 of Set 3 | zunyi
# Processing Record 27 of Set 3 | burnie
# Processing Record 28 of Set 3 | tynda
# Processing Record 29 of Set 3 | angoche
# Processing Record 30 of Set 3 | borogontsy
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | faya
# Processing Record 33 of Set 3 | moree
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | iguape
# Processing Record 36 of Set 3 | buala
# Processing Record 37 of Set 3 | porto novo
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | huilong
# Processing Record 40 of Set 3 | oranjemund
# Processing Record 41 of Set 3 | luanda
# Processing Record 42 of Set 3 | portland
# Processing Record 43 of Set 3 | tarrafal
# Processing Record 44 of Set 3 | saint-joseph
# Processing Record 45 of Set 3 | ahar
# Processing Record 46 of Set 3 | selcuk
# Processing Record 47 of Set 3 | butaritari
# Processing Record 48 of Set 3 | narsaq
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | kaita
# Processing Record 1 of Set 4 | gavrilovka vtoraya
# Processing Record 2 of Set 4 | asau
# Processing Record 3 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | methven
# Processing Record 6 of Set 4 | seredka
# Processing Record 7 of Set 4 | ust-kuyga
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | kavaratti
# Processing Record 10 of Set 4 | green valley
# Processing Record 11 of Set 4 | tautira
# Processing Record 12 of Set 4 | naze
# Processing Record 13 of Set 4 | zyryanka
# Processing Record 14 of Set 4 | ocampo
# Processing Record 15 of Set 4 | pundaguitan
# Processing Record 16 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 4 | north bend
# Processing Record 18 of Set 4 | baruun-urt
# Processing Record 19 of Set 4 | harlingen
# Processing Record 20 of Set 4 | nikolskoye
# Processing Record 21 of Set 4 | khatanga
# Processing Record 22 of Set 4 | chegdomyn
# Processing Record 23 of Set 4 | bilibino
# Processing Record 24 of Set 4 | shache
# Processing Record 25 of Set 4 | khorramshahr
# Processing Record 26 of Set 4 | madisonville
# Processing Record 27 of Set 4 | kajaani
# Processing Record 28 of Set 4 | rio grande
# Processing Record 29 of Set 4 | high level
# Processing Record 30 of Set 4 | sweetwater
# Processing Record 31 of Set 4 | san patricio
# Processing Record 32 of Set 4 | varhaug
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | mackay
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | vostok
# Processing Record 37 of Set 4 | lakselv
# Processing Record 38 of Set 4 | maumere
# Processing Record 39 of Set 4 | el alto
# Processing Record 40 of Set 4 | bulolo
# Processing Record 41 of Set 4 | okha
# Processing Record 42 of Set 4 | tubuala
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | kathmandu
# Processing Record 45 of Set 4 | sao jose da coroa grande
# Processing Record 46 of Set 4 | fuerte olimpo
# Processing Record 47 of Set 4 | ugoofaaru
# Processing Record 48 of Set 4 | fairview
# Processing Record 49 of Set 4 | mao
# Processing Record 50 of Set 4 | bismarck
# Processing Record 1 of Set 5 | aden
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | baghdad
# Processing Record 4 of Set 5 | santa isabel do rio negro
# Processing Record 5 of Set 5 | ozinki
# Processing Record 6 of Set 5 | yaring
# Processing Record 7 of Set 5 | guangyuan
# Processing Record 8 of Set 5 | pochutla
# Processing Record 9 of Set 5 | baiyin
# Processing Record 10 of Set 5 | matara
# Processing Record 11 of Set 5 | praia da vitoria
# Processing Record 12 of Set 5 | pacific grove
# Processing Record 13 of Set 5 | tongliao
# Processing Record 14 of Set 5 | bereda
# Processing Record 15 of Set 5 | adre
# Processing Record 16 of Set 5 | sorong
# Processing Record 17 of Set 5 | severo-kurilsk
# Processing Record 18 of Set 5 | east london
# Processing Record 19 of Set 5 | sawasawa
# City not found. Skipping...
# Processing Record 20 of Set 5 | nome
# Processing Record 21 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 5 | pinawa
# Processing Record 23 of Set 5 | merrill
# Processing Record 24 of Set 5 | sibolga
# Processing Record 25 of Set 5 | vila
# Processing Record 26 of Set 5 | mnogovershinnyy
# Processing Record 27 of Set 5 | churapcha
# Processing Record 28 of Set 5 | taltal
# Processing Record 29 of Set 5 | oga
# Processing Record 30 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 31 of Set 5 | paso de patria
# Processing Record 32 of Set 5 | teknaf
# Processing Record 33 of Set 5 | dunedin
# Processing Record 34 of Set 5 | sitka
# Processing Record 35 of Set 5 | bosaso
# Processing Record 36 of Set 5 | kautokeino
# Processing Record 37 of Set 5 | wuwei
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | kahului
# Processing Record 40 of Set 5 | bitkine
# Processing Record 41 of Set 5 | kuzino
# Processing Record 42 of Set 5 | acarau
# Processing Record 43 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | tromso
# Processing Record 45 of Set 5 | rock springs
# Processing Record 46 of Set 5 | adrar
# Processing Record 47 of Set 5 | boende
# Processing Record 48 of Set 5 | maceio
# Processing Record 49 of Set 5 | general roca
# Processing Record 50 of Set 5 | murgab
# Processing Record 1 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 6 | conway
# Processing Record 3 of Set 6 | teguise
# Processing Record 4 of Set 6 | hsinchu
# Processing Record 5 of Set 6 | chitral
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | ayagoz
# Processing Record 8 of Set 6 | namatanai
# Processing Record 9 of Set 6 | sorland
# Processing Record 10 of Set 6 | japura
# Processing Record 11 of Set 6 | lazaro cardenas
# Processing Record 12 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 6 | sar-e pul
# Processing Record 14 of Set 6 | longyearbyen
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | faanui
# Processing Record 17 of Set 6 | la palma
# Processing Record 18 of Set 6 | chokurdakh
# Processing Record 19 of Set 6 | chuy
# Processing Record 20 of Set 6 | sao miguel do araguaia
# Processing Record 21 of Set 6 | tambun
# Processing Record 22 of Set 6 | ballina
# Processing Record 23 of Set 6 | nanortalik
# Processing Record 24 of Set 6 | zhaoqing
# Processing Record 25 of Set 6 | mar del plata
# Processing Record 26 of Set 6 | salalah
# Processing Record 27 of Set 6 | karratha
# Processing Record 28 of Set 6 | maragogi
# Processing Record 29 of Set 6 | hualmay
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 6 | neiafu
# Processing Record 33 of Set 6 | arman
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 6 | san ramon
# Processing Record 37 of Set 6 | boguchany
# Processing Record 38 of Set 6 | port elizabeth
# Processing Record 39 of Set 6 | kodiak
# Processing Record 40 of Set 6 | sambava
# Processing Record 41 of Set 6 | bairiki
# Processing Record 42 of Set 6 | aklavik
# Processing Record 43 of Set 6 | iqaluit
# Processing Record 44 of Set 6 | kloulklubed
# Processing Record 45 of Set 6 | raudeberg
# Processing Record 46 of Set 6 | ghanzi
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | yakeshi
# Processing Record 49 of Set 6 | campbell river
# Processing Record 50 of Set 6 | munster
# Processing Record 1 of Set 7 | flagstaff
# Processing Record 2 of Set 7 | northam
# Processing Record 3 of Set 7 | evanston
# Processing Record 4 of Set 7 | stockton
# Processing Record 5 of Set 7 | ouadda
# Processing Record 6 of Set 7 | aurora
# Processing Record 7 of Set 7 | bethel
# Processing Record 8 of Set 7 | erzin
# Processing Record 9 of Set 7 | kelo
# Processing Record 10 of Set 7 | inuvik
# Processing Record 11 of Set 7 | brazzaville
# Processing Record 12 of Set 7 | fort nelson
# Processing Record 13 of Set 7 | smirnykh
# Processing Record 14 of Set 7 | dhidhdhoo
# Processing Record 15 of Set 7 | awjilah
# Processing Record 16 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 17 of Set 7 | palampur
# Processing Record 18 of Set 7 | poum
# Processing Record 19 of Set 7 | viedma
# Processing Record 20 of Set 7 | boissevain
# Processing Record 21 of Set 7 | cayenne
# Processing Record 22 of Set 7 | kruisfontein
# Processing Record 23 of Set 7 | kapit
# Processing Record 24 of Set 7 | olesno
# Processing Record 25 of Set 7 | neryungri
# Processing Record 26 of Set 7 | nsanje
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | johi
# Processing Record 29 of Set 7 | trinidad
# Processing Record 30 of Set 7 | tasiilaq
# Processing Record 31 of Set 7 | presidencia roque saenz pena
# Processing Record 32 of Set 7 | safford
# Processing Record 33 of Set 7 | coruripe
# Processing Record 34 of Set 7 | komsomolskiy
# Processing Record 35 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 7 | galveston
# Processing Record 37 of Set 7 | naples
# Processing Record 38 of Set 7 | bako
# Processing Record 39 of Set 7 | lata
# Processing Record 40 of Set 7 | walvis bay
# Processing Record 41 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 7 | tiznit
# Processing Record 43 of Set 7 | pauini
# Processing Record 44 of Set 7 | tilichiki
# Processing Record 45 of Set 7 | port blair
# Processing Record 46 of Set 7 | klaksvik
# Processing Record 47 of Set 7 | cabrera
# Processing Record 48 of Set 7 | olginskaya
# Processing Record 49 of Set 7 | vorontsovka
# Processing Record 50 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 8 | araouane
# Processing Record 2 of Set 8 | savannah bight
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | tonantins
# Processing Record 5 of Set 8 | margate
# Processing Record 6 of Set 8 | bogorodskoye
# Processing Record 7 of Set 8 | clyde river
# Processing Record 8 of Set 8 | mahebourg
# Processing Record 9 of Set 8 | ingham
# Processing Record 10 of Set 8 | taoudenni
# Processing Record 11 of Set 8 | kidal
# Processing Record 12 of Set 8 | suntar
# Processing Record 13 of Set 8 | fairbanks
# Processing Record 14 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 8 | sereflikochisar
# Processing Record 16 of Set 8 | bac lieu
# Processing Record 17 of Set 8 | manokwari
# Processing Record 18 of Set 8 | saint-augustin
# Processing Record 19 of Set 8 | tessalit
# Processing Record 20 of Set 8 | muyezerskiy
# Processing Record 21 of Set 8 | tiksi
# Processing Record 22 of Set 8 | guerrero negro
# Processing Record 23 of Set 8 | anori
# Processing Record 24 of Set 8 | martapura
# Processing Record 25 of Set 8 | pontianak
# Processing Record 26 of Set 8 | zhigansk
# Processing Record 27 of Set 8 | cap malheureux
# Processing Record 28 of Set 8 | chapais
# Processing Record 29 of Set 8 | belaya gora
# Processing Record 30 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 8 | ontario
# Processing Record 32 of Set 8 | corinto
# Processing Record 33 of Set 8 | northfield
# Processing Record 34 of Set 8 | tommot
# Processing Record 35 of Set 8 | carman
# Processing Record 36 of Set 8 | srednekolymsk
# Processing Record 37 of Set 8 | kopyevo
# City not found. Skipping...
# Processing Record 38 of Set 8 | severodvinsk
# Processing Record 39 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 8 | coquimbo
# Processing Record 41 of Set 8 | beira
# Processing Record 42 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 8 | anloga
# Processing Record 44 of Set 8 | harper
# Processing Record 45 of Set 8 | tingrela
# City not found. Skipping...
# Processing Record 46 of Set 8 | meulaboh
# Processing Record 47 of Set 8 | torbay
# Processing Record 48 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 8 | monroe
# Processing Record 1 of Set 9 | nalut
# Processing Record 2 of Set 9 | khor
# Processing Record 3 of Set 9 | byron bay
# Processing Record 4 of Set 9 | nkhata bay
# Processing Record 5 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 9 | samdrup jongkhar
# Processing Record 7 of Set 9 | port lincoln
# Processing Record 8 of Set 9 | kosh-agach
# Processing Record 9 of Set 9 | biak
# Processing Record 10 of Set 9 | carbonia
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | berezovyy
# Processing Record 13 of Set 9 | nantong
# Processing Record 14 of Set 9 | boysun
# Processing Record 15 of Set 9 | bonwapitse
# Processing Record 16 of Set 9 | biggar
# Processing Record 17 of Set 9 | amazar
# Processing Record 18 of Set 9 | hue
# Processing Record 19 of Set 9 | bethlehem
# Processing Record 20 of Set 9 | hambantota
# Processing Record 21 of Set 9 | maraba
# Processing Record 22 of Set 9 | chifeng
# Processing Record 23 of Set 9 | sheltozero
# Processing Record 24 of Set 9 | skibbereen
# Processing Record 25 of Set 9 | marzuq
# Processing Record 26 of Set 9 | braco do norte
# Processing Record 27 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 28 of Set 9 | east wenatchee bench
# Processing Record 29 of Set 9 | pangnirtung
# Processing Record 30 of Set 9 | gornopravdinsk
# Processing Record 31 of Set 9 | hirara
# Processing Record 32 of Set 9 | guanica
# Processing Record 33 of Set 9 | krasnyy chikoy
# Processing Record 34 of Set 9 | tambacounda
# Processing Record 35 of Set 9 | dingle
# Processing Record 36 of Set 9 | palmer
# Processing Record 37 of Set 9 | praya
# Processing Record 38 of Set 9 | kolokani
# Processing Record 39 of Set 9 | puerto del rosario
# Processing Record 40 of Set 9 | nacala
# Processing Record 41 of Set 9 | medina
# Processing Record 42 of Set 9 | le vauclin
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | dmytrivka
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | pasighat
# Processing Record 47 of Set 9 | kesennuma
# City not found. Skipping...
# Processing Record 48 of Set 9 | denau
# City not found. Skipping...
# Processing Record 49 of Set 9 | havoysund
# Processing Record 50 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 1 of Set 10 | ostersund
# Processing Record 2 of Set 10 | dongzhen
# Processing Record 3 of Set 10 | can
# Processing Record 4 of Set 10 | umarkot
# Processing Record 5 of Set 10 | paita
# Processing Record 6 of Set 10 | hay river
# Processing Record 7 of Set 10 | valparaiso
# Processing Record 8 of Set 10 | zheleznodorozhnyy
# Processing Record 9 of Set 10 | bay city
# Processing Record 10 of Set 10 | korsakov
# Processing Record 11 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 10 | george town
# Processing Record 13 of Set 10 | coulihaut
# City not found. Skipping...
# Processing Record 14 of Set 10 | syasstroy
# Processing Record 15 of Set 10 | zemio
# Processing Record 16 of Set 10 | esperance
# Processing Record 17 of Set 10 | hammerfest
# Processing Record 18 of Set 10 | yelan-kolenovskiy
# Processing Record 19 of Set 10 | lorengau
# Processing Record 20 of Set 10 | qostanay
# Processing Record 21 of Set 10 | hanzhong
# Processing Record 22 of Set 10 | lima
# Processing Record 23 of Set 10 | bilma
# Processing Record 24 of Set 10 | khasan
# Processing Record 25 of Set 10 | san carlos de bariloche
# Processing Record 26 of Set 10 | novaya mayna
# Processing Record 27 of Set 10 | atamanskaya
# Processing Record 28 of Set 10 | marsa matruh
# Processing Record 29 of Set 10 | kattivakkam
# Processing Record 30 of Set 10 | ilulissat
# Processing Record 31 of Set 10 | starozhilovo
# Processing Record 32 of Set 10 | wanning
# Processing Record 33 of Set 10 | romanovo
# Processing Record 34 of Set 10 | palaikastron
# Processing Record 35 of Set 10 | paracatu
# Processing Record 36 of Set 10 | beringovskiy
# Processing Record 37 of Set 10 | tshela
# Processing Record 38 of Set 10 | farafangana
# Processing Record 39 of Set 10 | mantua
# Processing Record 40 of Set 10 | gambela
# Processing Record 41 of Set 10 | goudomp
# City not found. Skipping...
# Processing Record 42 of Set 10 | riberalta
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | pitsunda
# Processing Record 45 of Set 10 | andenes
# Processing Record 46 of Set 10 | emba
# Processing Record 47 of Set 10 | irkutsk
# Processing Record 48 of Set 10 | poronaysk
# Processing Record 49 of Set 10 | pudozh
# Processing Record 50 of Set 10 | veraval
# Processing Record 1 of Set 11 | shingu
# Processing Record 2 of Set 11 | lawton
# Processing Record 3 of Set 11 | hokitika
# Processing Record 4 of Set 11 | kaka
# Processing Record 5 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 6 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 11 | rauma
# Processing Record 8 of Set 11 | sao joao da barra
# Processing Record 9 of Set 11 | warrnambool
# Processing Record 10 of Set 11 | mozarlandia
# Processing Record 11 of Set 11 | polunochnoye
# Processing Record 12 of Set 11 | staraya poltavka
# Processing Record 13 of Set 11 | la ronge
# Processing Record 14 of Set 11 | tupaciguara
# Processing Record 15 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 11 | hobyo
# Processing Record 17 of Set 11 | saint anthony
# Processing Record 18 of Set 11 | ullapool
# Processing Record 19 of Set 11 | voi
# Processing Record 20 of Set 11 | kaili
# Processing Record 21 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 11 | avera
# Processing Record 23 of Set 11 | nelson bay
# Processing Record 24 of Set 11 | amapa
# Processing Record 25 of Set 11 | anamur
# Processing Record 26 of Set 11 | tabuk
# Processing Record 27 of Set 11 | bom jesus da lapa
# Processing Record 28 of Set 11 | bambanglipuro
# Processing Record 29 of Set 11 | jinka
# Processing Record 30 of Set 11 | tomatlan
# Processing Record 31 of Set 11 | yuancheng
# Processing Record 32 of Set 11 | piacabucu
# Processing Record 33 of Set 11 | sabang
# Processing Record 34 of Set 11 | egvekinot
# Processing Record 35 of Set 11 | xining
# Processing Record 36 of Set 11 | pemangkat
# Processing Record 37 of Set 11 | okhotsk
# Processing Record 38 of Set 11 | lamar
# Processing Record 39 of Set 11 | labuan
# Processing Record 40 of Set 11 | quatre cocos
# Processing Record 41 of Set 11 | sistranda
# Processing Record 42 of Set 11 | capaccio
# Processing Record 43 of Set 11 | puerto colombia
# Processing Record 44 of Set 11 | vao
# Processing Record 45 of Set 11 | ulaangom
# Processing Record 46 of Set 11 | hamilton
# Processing Record 47 of Set 11 | copiapo
# Processing Record 48 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 11 | amvrosiyivka
# Processing Record 50 of Set 11 | melilla
# Processing Record 1 of Set 12 | jalu
# Processing Record 2 of Set 12 | belmonte
# Processing Record 3 of Set 12 | kaeo
# Processing Record 4 of Set 12 | arak
# Processing Record 5 of Set 12 | aswan
# Processing Record 6 of Set 12 | arrecife
# Processing Record 7 of Set 12 | hami
# Processing Record 8 of Set 12 | aksu
# Processing Record 9 of Set 12 | hampton
# Processing Record 10 of Set 12 | duekoue
# Processing Record 11 of Set 12 | yerbogachen
# Processing Record 12 of Set 12 | quelimane
# Processing Record 13 of Set 12 | dali
# Processing Record 14 of Set 12 | ambilobe
# Processing Record 15 of Set 12 | cabo san lucas
# Processing Record 16 of Set 12 | kritsa
# Processing Record 17 of Set 12 | gizo
# Processing Record 18 of Set 12 | coihaique
# Processing Record 19 of Set 12 | razole
# Processing Record 20 of Set 12 | gat
# Processing Record 21 of Set 12 | yumen
# Processing Record 22 of Set 12 | batemans bay
# Processing Record 23 of Set 12 | alice springs
# Processing Record 24 of Set 12 | serra
# Processing Record 25 of Set 12 | mbanza-ngungu
# Processing Record 26 of Set 12 | juneau
# Processing Record 27 of Set 12 | broome
# Processing Record 28 of Set 12 | casablanca
# Processing Record 29 of Set 12 | fuxin
# Processing Record 30 of Set 12 | piedras amarillas
# City not found. Skipping...
# Processing Record 31 of Set 12 | rudnogorsk
# Processing Record 32 of Set 12 | taksimo
# Processing Record 33 of Set 12 | bumbuna
# Processing Record 34 of Set 12 | itarema
# Processing Record 35 of Set 12 | padampur
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | kumluca
# Processing Record 38 of Set 12 | north platte
# Processing Record 39 of Set 12 | ganzhou
# Processing Record 40 of Set 12 | carutapera
# Processing Record 41 of Set 12 | chicama
# Processing Record 42 of Set 12 | ndele
# Processing Record 43 of Set 12 | bani
# Processing Record 44 of Set 12 | lagoa
# Processing Record 45 of Set 12 | kiunga
# Processing Record 46 of Set 12 | jacareacanga
# Processing Record 47 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 12 | sovetsk
# Processing Record 49 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 13 | kashi
# Processing Record 2 of Set 13 | bardsir
# Processing Record 3 of Set 13 | peachland
# Processing Record 4 of Set 13 | padang
# Processing Record 5 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 13 | college
# Processing Record 7 of Set 13 | udachnyy
# Processing Record 8 of Set 13 | kichmengskiy gorodok
# Processing Record 9 of Set 13 | banda aceh
# Processing Record 10 of Set 13 | lac du bonnet
# Processing Record 11 of Set 13 | nicolas bravo
# Processing Record 12 of Set 13 | asyut
# Processing Record 13 of Set 13 | terme
# Processing Record 14 of Set 13 | zhezkazgan
# Processing Record 15 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 16 of Set 13 | ikongo
# Processing Record 17 of Set 13 | neuquen
# Processing Record 18 of Set 13 | behshahr
# Processing Record 19 of Set 13 | chumikan
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 564

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp   Current Description  \
# 0      san ignacio  17.1561  -89.0714     78.80      scattered clouds
# 1       marienburg  54.0359   19.0266     36.00            few clouds
# 2        cape town -33.9258   18.4232     63.00             clear sky
# 3          rikitea -23.1203 -134.9692     71.44  heavy intensity rain
# 4      deputatskiy  69.3000  139.9000      6.67       overcast clouds
# 5  haines junction  60.7522 -137.5108     26.60            light snow
# 6            kapaa  22.0752 -159.3190     78.80         broken clouds
# 7   saint-philippe -21.3585   55.7679     77.00       overcast clouds
# 8         thompson  55.7435  -97.8558     39.20       overcast clouds
# 9          mayumba  -3.4320   10.6554     77.76            light rain
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00           0.00        69          40        6.91      BZ
# 1           0.00           0.00       100          16        6.35      PL
# 2           0.00           0.00        82           0        6.91      ZA
# 3           4.40           0.00        91         100        3.91      PF
# 4           0.00           0.00        88         100        2.84      RU
# 5           0.00           0.13        50         100       12.66      CA
# 6           0.00           0.00        65          75       18.41      US
# 7           0.00           0.00        73          90       10.36      RE
# 8           0.00           0.00        52          90        2.30      CA
# 9           0.25           0.00        87          95        5.35      GA

# %%
output_data_file = 'Weather_database.csv'

# %%
city_data_df.to_csv(output_data_file, index_label='City_ID')
